# %% [markdown]
# # Probability Practice

# %% [markdown]
# ## What is Probability?

# %% [markdown]
# > **Probability is the likelihood of a specific outcome occuring out of all possible outcomes, expressed as a fraction between 0 and 1.**
#
# Perhaps more importantly:
#
# > **"Probabilities do not tell us what will happen for sure; they tell us what is _likely to happen_ and what is _less likely to happen_."**
# >
# > -- _Naked Statistics_, by Charles Wheelan, p. 72

# %% [markdown]
# In general, you can think of dividing the outcome you're exploring by all possible outcomes:
#
# $$ P(Event) = \frac{|Event|}{|Sample\ Space|} $$

# %% [markdown]
# ## Planning Party Playlists with Probabilities & Combinatorics

# %% [markdown]
# - We are constructing a dinner party playlist for a gathering we are planning.
# - We asked our attendees to each provide a handful of songs they would like to be played at the dinner party.

# %%
# Imports
import pandas as pd
import numpy as np
import math
import itertools

# %%
# This code might be a bit different from anything you've seen before...
# Point is, it grabs each of the CSVs in a folder and reads them in 
import os, glob

datafolder = "probability_playlists/"
rec_files = glob.glob(datafolder+"*.csv")

playlists = {}
for file in rec_files:
    key = os.path.basename(file).replace('_recs.csv','')
    playlists[key] = pd.read_csv(file)
playlists.keys()
# Out:
# dict_keys(['joe', 'james', 'anne', 'john', 'samantha'])

# %%
for name, playlist in playlists.items():
    print(f"{name.title()}'s Requests:")
    display(playlist)
# Out:
# Joe's Requests:
#         artist              track Recommended By
# 0    Green Day  Time of your Life            Joe
# 1        B-52s       Rock Lobster            Joe
# 2    Lady GaGa         Poker Face            Joe
# 3  John Lennon            Imagine            Joe
# James's Requests:
#                   artist                            track Recommended By
# 0                  Eve 6              Here's to the Night          James
# 1     Neutral Milk Hotel  Into the Aeroplane Over the Sea          James
# 2             Rilo Kiley           With Arms Outstretched          James
# 3  Red Hot Chili Peppers                        Otherside          James
# Anne's Requests:
#               artist                 track Recommended By
# 0  Smashing Pumpkins      Tonight, Tonight           Anne
# 1    Black Eyed Peas  Let's Get it Started           Anne
# 2          Green Day     Time of your Life           Anne
# John's Requests:
#             artist                 track Recommended By
# 0  Black Eyed Peas  Let's Get it Started           John
# 1        Lady GaGa            Poker Face           John
# 2        Lady GaGa           Bad Romance           John
# 3        Lady GaGa            Just Dance           John
# Samantha's Requests:
#                artist                 track Recommended By
# 0     Black Eyed Peas  Let's Get it Started       Samantha
# 1  Panic at the Disco            Hallelujah       Samantha
# 2               Adele  Set Fire to the Rain       Samantha

# %% [markdown]
# For now, lets assume we take everyone's recommendations and add them all to our playlist, even if the same song has been recommended by someone else.

# %%
# Create 1 df for all recs
df = pd.concat(playlists).reset_index(drop=True)
df
# Out:
#                    artist                            track Recommended By
# 0               Green Day                Time of your Life            Joe
# 1                   B-52s                     Rock Lobster            Joe
# 2               Lady GaGa                       Poker Face            Joe
# 3             John Lennon                          Imagine            Joe
# 4                   Eve 6              Here's to the Night          James
# 5      Neutral Milk Hotel  Into the Aeroplane Over the Sea          James
# 6              Rilo Kiley           With Arms Outstretched          James
# 7   Red Hot Chili Peppers                        Otherside          James
# 8       Smashing Pumpkins                 Tonight, Tonight           Anne
# 9         Black Eyed Peas             Let's Get it Started           Anne
# 10              Green Day                Time of your Life           Anne
# 11        Black Eyed Peas             Let's Get it Started           John
# 12              Lady GaGa                       Poker Face           John
# 13              Lady GaGa                      Bad Romance           John
# 14              Lady GaGa                       Just Dance           John
# 15        Black Eyed Peas             Let's Get it Started       Samantha
# 16     Panic at the Disco                       Hallelujah       Samantha
# 17                  Adele             Set Fire to the Rain       Samantha

# %% [markdown]
# ### Q1: What is the probability of the next song being by Lady Gaga?

# %% [markdown]
# Assume we just accept everyone's suggestions allowing duplicate songs and play on shuffle.
#
# Remember:
#
#
# $$ P(E) = \frac{|E|}{|S|} $$

# %%
# Set up: number of songs, grouped by artist
df['artist'].value_counts()
# Out:
# Lady GaGa                4
# Black Eyed Peas          3
# Green Day                2
# Smashing Pumpkins        1
# Panic at the Disco       1
# Red Hot Chili Peppers    1
# Neutral Milk Hotel       1
# Rilo Kiley               1
# Eve 6                    1
# B-52s                    1
# Adele                    1
# John Lennon              1
# Name: artist, dtype: int64

# %%
# What is the event space?
E = df.loc[df['artist'] == 'Lady GaGa'].shape[0]
E
# Out:
# 4

# %%
# What about the sample space? 
S = df.shape[0]
S
# Out:
# 18

# %%
# Find the probability of lady gaga playing
P_lady_gaga = E / S
P_lady_gaga
# Out:
# 0.2222222222222222

# %% [markdown]
# ### Q2: What is the probability of the next song being "Time of Your Life"?

# %%
# Set Up
df['track'].value_counts()
# Out:
# Let's Get it Started               3
# Poker Face                         2
# Time of your Life                  2
# Hallelujah                         1
# Rock Lobster                       1
# With Arms Outstretched             1
# Set Fire to the Rain               1
# Otherside                          1
# Bad Romance                        1
# Here's to the Night                1
# Into the Aeroplane Over the Sea    1
# Imagine                            1
# Just Dance                         1
# Tonight, Tonight                   1
# Name: track, dtype: int64

# %%
# Event space?
E = df.loc[df['track'] == "Time of your Life"].shape[0]
E
# Out:
# 2

# %%
# Sample space?
S = df.shape[0]
S
# Out:
# 18

# %%
# Probability of 'Time of yYour Life'
P_time_of_your_life = E / S
P_time_of_your_life
# Out:
# 0.1111111111111111

# %% [markdown]
# ### Q3: what is the probability of hearing a song by Lady GaGa or Green Day?

# %%
# Set up
df['artist'].value_counts()
# Out:
# Lady GaGa                4
# Black Eyed Peas          3
# Green Day                2
# Smashing Pumpkins        1
# Panic at the Disco       1
# Red Hot Chili Peppers    1
# Neutral Milk Hotel       1
# Rilo Kiley               1
# Eve 6                    1
# B-52s                    1
# Adele                    1
# John Lennon              1
# Name: artist, dtype: int64

# %%
P_greenday = E = df.loc[df['artist'] == 'Green Day'].shape[0]/df.shape[0]
P_greenday
# Out:
# 0.1111111111111111

# %%
# Event Space
E = None

# %%
# Sample space
S = None

# %%
# Find the probability
P_lady_gaga_or_greenday = P_lady_gaga + P_greenday
P_lady_gaga_or_greenday
# Out:
# 0.3333333333333333

# %% [markdown]
# ### Q4: How many different ways could we build a playlist using everyone's recommendations (without shuffle, no looping, and no repeated songs)?

# %%
# First, let's deal with those duplicates we've been ignoring
df = df.drop_duplicates(subset=['artist', 'track'])
df
# Out:
#                    artist                            track Recommended By
# 0               Green Day                Time of your Life            Joe
# 1                   B-52s                     Rock Lobster            Joe
# 2               Lady GaGa                       Poker Face            Joe
# 3             John Lennon                          Imagine            Joe
# 4                   Eve 6              Here's to the Night          James
# 5      Neutral Milk Hotel  Into the Aeroplane Over the Sea          James
# 6              Rilo Kiley           With Arms Outstretched          James
# 7   Red Hot Chili Peppers                        Otherside          James
# 8       Smashing Pumpkins                 Tonight, Tonight           Anne
# 9         Black Eyed Peas             Let's Get it Started           Anne
# 13              Lady GaGa                      Bad Romance           John
# 14              Lady GaGa                       Just Dance           John
# 16     Panic at the Disco                       Hallelujah       Samantha
# 17                  Adele             Set Fire to the Rain       Samantha

# %%
songs = list(df['track'].values)

# %%
u_playlists = list(itertools.combinations(songs, 4))
u_playlists
# Out:
# [('Time of your Life', 'Rock Lobster', 'Poker Face', 'Imagine'),
#  ('Time of your Life', 'Rock Lobster', 'Poker Face', "Here's to the Night"),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea'),
#  ('Time of your Life', 'Rock Lobster', 'Poker Face', 'With Arms Outstretched'),
#  ('Time of your Life', 'Rock Lobster', 'Poker Face', 'Otherside'),
#  ('Time of your Life', 'Rock Lobster', 'Poker Face', 'Tonight, Tonight'),
#  ('Time of your Life', 'Rock Lobster', 'Poker Face', "Let's Get it Started"),
#  ('Time of your Life', 'Rock Lobster', 'Poker Face', 'Bad Romance'),
#  ('Time of your Life', 'Rock Lobster', 'Poker Face', 'Just Dance'),
#  ('Time of your Life', 'Rock Lobster', 'Poker Face', 'Hallelujah'),
#  ('Time of your Life', 'Rock Lobster', 'Poker Face', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Rock Lobster', 'Imagine', "Here's to the Night"),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Imagine',
#   'Into the Aeroplane Over the Sea'),
#  ('Time of your Life', 'Rock Lobster', 'Imagine', 'With Arms Outstretched'),
#  ('Time of your Life', 'Rock Lobster', 'Imagine', 'Otherside'),
#  ('Time of your Life', 'Rock Lobster', 'Imagine', 'Tonight, Tonight'),
#  ('Time of your Life', 'Rock Lobster', 'Imagine', "Let's Get it Started"),
#  ('Time of your Life', 'Rock Lobster', 'Imagine', 'Bad Romance'),
#  ('Time of your Life', 'Rock Lobster', 'Imagine', 'Just Dance'),
#  ('Time of your Life', 'Rock Lobster', 'Imagine', 'Hallelujah'),
#  ('Time of your Life', 'Rock Lobster', 'Imagine', 'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Rock Lobster',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea'),
#  ('Time of your Life',
#   'Rock Lobster',
#   "Here's to the Night",
#   'With Arms Outstretched'),
#  ('Time of your Life', 'Rock Lobster', "Here's to the Night", 'Otherside'),
#  ('Time of your Life',
#   'Rock Lobster',
#   "Here's to the Night",
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Rock Lobster',
#   "Here's to the Night",
#   "Let's Get it Started"),
#  ('Time of your Life', 'Rock Lobster', "Here's to the Night", 'Bad Romance'),
#  ('Time of your Life', 'Rock Lobster', "Here's to the Night", 'Just Dance'),
#  ('Time of your Life', 'Rock Lobster', "Here's to the Night", 'Hallelujah'),
#  ('Time of your Life',
#   'Rock Lobster',
#   "Here's to the Night",
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Otherside'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Just Dance'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Hallelujah'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Rock Lobster', 'With Arms Outstretched', 'Otherside'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'With Arms Outstretched',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'With Arms Outstretched',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   'Rock Lobster',
#   'With Arms Outstretched',
#   'Bad Romance'),
#  ('Time of your Life', 'Rock Lobster', 'With Arms Outstretched', 'Just Dance'),
#  ('Time of your Life', 'Rock Lobster', 'With Arms Outstretched', 'Hallelujah'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'With Arms Outstretched',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Rock Lobster', 'Otherside', 'Tonight, Tonight'),
#  ('Time of your Life', 'Rock Lobster', 'Otherside', "Let's Get it Started"),
#  ('Time of your Life', 'Rock Lobster', 'Otherside', 'Bad Romance'),
#  ('Time of your Life', 'Rock Lobster', 'Otherside', 'Just Dance'),
#  ('Time of your Life', 'Rock Lobster', 'Otherside', 'Hallelujah'),
#  ('Time of your Life', 'Rock Lobster', 'Otherside', 'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Time of your Life', 'Rock Lobster', 'Tonight, Tonight', 'Bad Romance'),
#  ('Time of your Life', 'Rock Lobster', 'Tonight, Tonight', 'Just Dance'),
#  ('Time of your Life', 'Rock Lobster', 'Tonight, Tonight', 'Hallelujah'),
#  ('Time of your Life',
#   'Rock Lobster',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Rock Lobster', "Let's Get it Started", 'Bad Romance'),
#  ('Time of your Life', 'Rock Lobster', "Let's Get it Started", 'Just Dance'),
#  ('Time of your Life', 'Rock Lobster', "Let's Get it Started", 'Hallelujah'),
#  ('Time of your Life',
#   'Rock Lobster',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Rock Lobster', 'Bad Romance', 'Just Dance'),
#  ('Time of your Life', 'Rock Lobster', 'Bad Romance', 'Hallelujah'),
#  ('Time of your Life', 'Rock Lobster', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Rock Lobster', 'Just Dance', 'Hallelujah'),
#  ('Time of your Life', 'Rock Lobster', 'Just Dance', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Rock Lobster', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Poker Face', 'Imagine', "Here's to the Night"),
#  ('Time of your Life',
#   'Poker Face',
#   'Imagine',
#   'Into the Aeroplane Over the Sea'),
#  ('Time of your Life', 'Poker Face', 'Imagine', 'With Arms Outstretched'),
#  ('Time of your Life', 'Poker Face', 'Imagine', 'Otherside'),
#  ('Time of your Life', 'Poker Face', 'Imagine', 'Tonight, Tonight'),
#  ('Time of your Life', 'Poker Face', 'Imagine', "Let's Get it Started"),
#  ('Time of your Life', 'Poker Face', 'Imagine', 'Bad Romance'),
#  ('Time of your Life', 'Poker Face', 'Imagine', 'Just Dance'),
#  ('Time of your Life', 'Poker Face', 'Imagine', 'Hallelujah'),
#  ('Time of your Life', 'Poker Face', 'Imagine', 'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea'),
#  ('Time of your Life',
#   'Poker Face',
#   "Here's to the Night",
#   'With Arms Outstretched'),
#  ('Time of your Life', 'Poker Face', "Here's to the Night", 'Otherside'),
#  ('Time of your Life',
#   'Poker Face',
#   "Here's to the Night",
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Poker Face',
#   "Here's to the Night",
#   "Let's Get it Started"),
#  ('Time of your Life', 'Poker Face', "Here's to the Night", 'Bad Romance'),
#  ('Time of your Life', 'Poker Face', "Here's to the Night", 'Just Dance'),
#  ('Time of your Life', 'Poker Face', "Here's to the Night", 'Hallelujah'),
#  ('Time of your Life',
#   'Poker Face',
#   "Here's to the Night",
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched'),
#  ('Time of your Life',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Otherside'),
#  ('Time of your Life',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance'),
#  ('Time of your Life',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Just Dance'),
#  ('Time of your Life',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Hallelujah'),
#  ('Time of your Life',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Poker Face', 'With Arms Outstretched', 'Otherside'),
#  ('Time of your Life',
#   'Poker Face',
#   'With Arms Outstretched',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Poker Face',
#   'With Arms Outstretched',
#   "Let's Get it Started"),
#  ('Time of your Life', 'Poker Face', 'With Arms Outstretched', 'Bad Romance'),
#  ('Time of your Life', 'Poker Face', 'With Arms Outstretched', 'Just Dance'),
#  ('Time of your Life', 'Poker Face', 'With Arms Outstretched', 'Hallelujah'),
#  ('Time of your Life',
#   'Poker Face',
#   'With Arms Outstretched',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Poker Face', 'Otherside', 'Tonight, Tonight'),
#  ('Time of your Life', 'Poker Face', 'Otherside', "Let's Get it Started"),
#  ('Time of your Life', 'Poker Face', 'Otherside', 'Bad Romance'),
#  ('Time of your Life', 'Poker Face', 'Otherside', 'Just Dance'),
#  ('Time of your Life', 'Poker Face', 'Otherside', 'Hallelujah'),
#  ('Time of your Life', 'Poker Face', 'Otherside', 'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Poker Face',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Time of your Life', 'Poker Face', 'Tonight, Tonight', 'Bad Romance'),
#  ('Time of your Life', 'Poker Face', 'Tonight, Tonight', 'Just Dance'),
#  ('Time of your Life', 'Poker Face', 'Tonight, Tonight', 'Hallelujah'),
#  ('Time of your Life',
#   'Poker Face',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Poker Face', "Let's Get it Started", 'Bad Romance'),
#  ('Time of your Life', 'Poker Face', "Let's Get it Started", 'Just Dance'),
#  ('Time of your Life', 'Poker Face', "Let's Get it Started", 'Hallelujah'),
#  ('Time of your Life',
#   'Poker Face',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Poker Face', 'Bad Romance', 'Just Dance'),
#  ('Time of your Life', 'Poker Face', 'Bad Romance', 'Hallelujah'),
#  ('Time of your Life', 'Poker Face', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Poker Face', 'Just Dance', 'Hallelujah'),
#  ('Time of your Life', 'Poker Face', 'Just Dance', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Poker Face', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Imagine',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea'),
#  ('Time of your Life',
#   'Imagine',
#   "Here's to the Night",
#   'With Arms Outstretched'),
#  ('Time of your Life', 'Imagine', "Here's to the Night", 'Otherside'),
#  ('Time of your Life', 'Imagine', "Here's to the Night", 'Tonight, Tonight'),
#  ('Time of your Life',
#   'Imagine',
#   "Here's to the Night",
#   "Let's Get it Started"),
#  ('Time of your Life', 'Imagine', "Here's to the Night", 'Bad Romance'),
#  ('Time of your Life', 'Imagine', "Here's to the Night", 'Just Dance'),
#  ('Time of your Life', 'Imagine', "Here's to the Night", 'Hallelujah'),
#  ('Time of your Life',
#   'Imagine',
#   "Here's to the Night",
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched'),
#  ('Time of your Life',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Otherside'),
#  ('Time of your Life',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance'),
#  ('Time of your Life',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Just Dance'),
#  ('Time of your Life',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Hallelujah'),
#  ('Time of your Life',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Imagine', 'With Arms Outstretched', 'Otherside'),
#  ('Time of your Life',
#   'Imagine',
#   'With Arms Outstretched',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Imagine',
#   'With Arms Outstretched',
#   "Let's Get it Started"),
#  ('Time of your Life', 'Imagine', 'With Arms Outstretched', 'Bad Romance'),
#  ('Time of your Life', 'Imagine', 'With Arms Outstretched', 'Just Dance'),
#  ('Time of your Life', 'Imagine', 'With Arms Outstretched', 'Hallelujah'),
#  ('Time of your Life',
#   'Imagine',
#   'With Arms Outstretched',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Imagine', 'Otherside', 'Tonight, Tonight'),
#  ('Time of your Life', 'Imagine', 'Otherside', "Let's Get it Started"),
#  ('Time of your Life', 'Imagine', 'Otherside', 'Bad Romance'),
#  ('Time of your Life', 'Imagine', 'Otherside', 'Just Dance'),
#  ('Time of your Life', 'Imagine', 'Otherside', 'Hallelujah'),
#  ('Time of your Life', 'Imagine', 'Otherside', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Imagine', 'Tonight, Tonight', "Let's Get it Started"),
#  ('Time of your Life', 'Imagine', 'Tonight, Tonight', 'Bad Romance'),
#  ('Time of your Life', 'Imagine', 'Tonight, Tonight', 'Just Dance'),
#  ('Time of your Life', 'Imagine', 'Tonight, Tonight', 'Hallelujah'),
#  ('Time of your Life', 'Imagine', 'Tonight, Tonight', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Imagine', "Let's Get it Started", 'Bad Romance'),
#  ('Time of your Life', 'Imagine', "Let's Get it Started", 'Just Dance'),
#  ('Time of your Life', 'Imagine', "Let's Get it Started", 'Hallelujah'),
#  ('Time of your Life',
#   'Imagine',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Imagine', 'Bad Romance', 'Just Dance'),
#  ('Time of your Life', 'Imagine', 'Bad Romance', 'Hallelujah'),
#  ('Time of your Life', 'Imagine', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Imagine', 'Just Dance', 'Hallelujah'),
#  ('Time of your Life', 'Imagine', 'Just Dance', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Imagine', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Otherside'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Just Dance'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Hallelujah'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Otherside'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Bad Romance'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Just Dance'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Hallelujah'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Set Fire to the Rain'),
#  ('Time of your Life', "Here's to the Night", 'Otherside', 'Tonight, Tonight'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Otherside',
#   "Let's Get it Started"),
#  ('Time of your Life', "Here's to the Night", 'Otherside', 'Bad Romance'),
#  ('Time of your Life', "Here's to the Night", 'Otherside', 'Just Dance'),
#  ('Time of your Life', "Here's to the Night", 'Otherside', 'Hallelujah'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Otherside',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Tonight, Tonight',
#   'Bad Romance'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Tonight, Tonight',
#   'Just Dance'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Tonight, Tonight',
#   'Hallelujah'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   "Here's to the Night",
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Time of your Life',
#   "Here's to the Night",
#   "Let's Get it Started",
#   'Just Dance'),
#  ('Time of your Life',
#   "Here's to the Night",
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('Time of your Life',
#   "Here's to the Night",
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Time of your Life', "Here's to the Night", 'Bad Romance', 'Just Dance'),
#  ('Time of your Life', "Here's to the Night", 'Bad Romance', 'Hallelujah'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Time of your Life', "Here's to the Night", 'Just Dance', 'Hallelujah'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   "Here's to the Night",
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Otherside'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Bad Romance'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Just Dance'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Hallelujah'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Bad Romance'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Just Dance'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Hallelujah'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Bad Romance'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Just Dance'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Hallelujah'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Just Dance'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance',
#   'Just Dance'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance',
#   'Hallelujah'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Just Dance',
#   'Hallelujah'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Into the Aeroplane Over the Sea',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Otherside',
#   'Tonight, Tonight'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Otherside',
#   "Let's Get it Started"),
#  ('Time of your Life', 'With Arms Outstretched', 'Otherside', 'Bad Romance'),
#  ('Time of your Life', 'With Arms Outstretched', 'Otherside', 'Just Dance'),
#  ('Time of your Life', 'With Arms Outstretched', 'Otherside', 'Hallelujah'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Otherside',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Bad Romance'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Just Dance'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Hallelujah'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Just Dance'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'With Arms Outstretched', 'Bad Romance', 'Just Dance'),
#  ('Time of your Life', 'With Arms Outstretched', 'Bad Romance', 'Hallelujah'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'With Arms Outstretched', 'Just Dance', 'Hallelujah'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'With Arms Outstretched',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Otherside',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Time of your Life', 'Otherside', 'Tonight, Tonight', 'Bad Romance'),
#  ('Time of your Life', 'Otherside', 'Tonight, Tonight', 'Just Dance'),
#  ('Time of your Life', 'Otherside', 'Tonight, Tonight', 'Hallelujah'),
#  ('Time of your Life',
#   'Otherside',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Otherside', "Let's Get it Started", 'Bad Romance'),
#  ('Time of your Life', 'Otherside', "Let's Get it Started", 'Just Dance'),
#  ('Time of your Life', 'Otherside', "Let's Get it Started", 'Hallelujah'),
#  ('Time of your Life',
#   'Otherside',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Otherside', 'Bad Romance', 'Just Dance'),
#  ('Time of your Life', 'Otherside', 'Bad Romance', 'Hallelujah'),
#  ('Time of your Life', 'Otherside', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Otherside', 'Just Dance', 'Hallelujah'),
#  ('Time of your Life', 'Otherside', 'Just Dance', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Otherside', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Time of your Life',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Just Dance'),
#  ('Time of your Life',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('Time of your Life',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Tonight, Tonight', 'Bad Romance', 'Just Dance'),
#  ('Time of your Life', 'Tonight, Tonight', 'Bad Romance', 'Hallelujah'),
#  ('Time of your Life',
#   'Tonight, Tonight',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Tonight, Tonight', 'Just Dance', 'Hallelujah'),
#  ('Time of your Life',
#   'Tonight, Tonight',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   'Tonight, Tonight',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Time of your Life', "Let's Get it Started", 'Bad Romance', 'Just Dance'),
#  ('Time of your Life', "Let's Get it Started", 'Bad Romance', 'Hallelujah'),
#  ('Time of your Life',
#   "Let's Get it Started",
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Time of your Life', "Let's Get it Started", 'Just Dance', 'Hallelujah'),
#  ('Time of your Life',
#   "Let's Get it Started",
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Time of your Life',
#   "Let's Get it Started",
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Time of your Life', 'Bad Romance', 'Just Dance', 'Hallelujah'),
#  ('Time of your Life', 'Bad Romance', 'Just Dance', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Bad Romance', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Time of your Life', 'Just Dance', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Poker Face', 'Imagine', "Here's to the Night"),
#  ('Rock Lobster', 'Poker Face', 'Imagine', 'Into the Aeroplane Over the Sea'),
#  ('Rock Lobster', 'Poker Face', 'Imagine', 'With Arms Outstretched'),
#  ('Rock Lobster', 'Poker Face', 'Imagine', 'Otherside'),
#  ('Rock Lobster', 'Poker Face', 'Imagine', 'Tonight, Tonight'),
#  ('Rock Lobster', 'Poker Face', 'Imagine', "Let's Get it Started"),
#  ('Rock Lobster', 'Poker Face', 'Imagine', 'Bad Romance'),
#  ('Rock Lobster', 'Poker Face', 'Imagine', 'Just Dance'),
#  ('Rock Lobster', 'Poker Face', 'Imagine', 'Hallelujah'),
#  ('Rock Lobster', 'Poker Face', 'Imagine', 'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea'),
#  ('Rock Lobster',
#   'Poker Face',
#   "Here's to the Night",
#   'With Arms Outstretched'),
#  ('Rock Lobster', 'Poker Face', "Here's to the Night", 'Otherside'),
#  ('Rock Lobster', 'Poker Face', "Here's to the Night", 'Tonight, Tonight'),
#  ('Rock Lobster', 'Poker Face', "Here's to the Night", "Let's Get it Started"),
#  ('Rock Lobster', 'Poker Face', "Here's to the Night", 'Bad Romance'),
#  ('Rock Lobster', 'Poker Face', "Here's to the Night", 'Just Dance'),
#  ('Rock Lobster', 'Poker Face', "Here's to the Night", 'Hallelujah'),
#  ('Rock Lobster', 'Poker Face', "Here's to the Night", 'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched'),
#  ('Rock Lobster',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Otherside'),
#  ('Rock Lobster',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight'),
#  ('Rock Lobster',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started"),
#  ('Rock Lobster',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance'),
#  ('Rock Lobster',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Just Dance'),
#  ('Rock Lobster',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Hallelujah'),
#  ('Rock Lobster',
#   'Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'Poker Face', 'With Arms Outstretched', 'Otherside'),
#  ('Rock Lobster', 'Poker Face', 'With Arms Outstretched', 'Tonight, Tonight'),
#  ('Rock Lobster',
#   'Poker Face',
#   'With Arms Outstretched',
#   "Let's Get it Started"),
#  ('Rock Lobster', 'Poker Face', 'With Arms Outstretched', 'Bad Romance'),
#  ('Rock Lobster', 'Poker Face', 'With Arms Outstretched', 'Just Dance'),
#  ('Rock Lobster', 'Poker Face', 'With Arms Outstretched', 'Hallelujah'),
#  ('Rock Lobster',
#   'Poker Face',
#   'With Arms Outstretched',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'Poker Face', 'Otherside', 'Tonight, Tonight'),
#  ('Rock Lobster', 'Poker Face', 'Otherside', "Let's Get it Started"),
#  ('Rock Lobster', 'Poker Face', 'Otherside', 'Bad Romance'),
#  ('Rock Lobster', 'Poker Face', 'Otherside', 'Just Dance'),
#  ('Rock Lobster', 'Poker Face', 'Otherside', 'Hallelujah'),
#  ('Rock Lobster', 'Poker Face', 'Otherside', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Poker Face', 'Tonight, Tonight', "Let's Get it Started"),
#  ('Rock Lobster', 'Poker Face', 'Tonight, Tonight', 'Bad Romance'),
#  ('Rock Lobster', 'Poker Face', 'Tonight, Tonight', 'Just Dance'),
#  ('Rock Lobster', 'Poker Face', 'Tonight, Tonight', 'Hallelujah'),
#  ('Rock Lobster', 'Poker Face', 'Tonight, Tonight', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Poker Face', "Let's Get it Started", 'Bad Romance'),
#  ('Rock Lobster', 'Poker Face', "Let's Get it Started", 'Just Dance'),
#  ('Rock Lobster', 'Poker Face', "Let's Get it Started", 'Hallelujah'),
#  ('Rock Lobster',
#   'Poker Face',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'Poker Face', 'Bad Romance', 'Just Dance'),
#  ('Rock Lobster', 'Poker Face', 'Bad Romance', 'Hallelujah'),
#  ('Rock Lobster', 'Poker Face', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Poker Face', 'Just Dance', 'Hallelujah'),
#  ('Rock Lobster', 'Poker Face', 'Just Dance', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Poker Face', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Imagine',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea'),
#  ('Rock Lobster', 'Imagine', "Here's to the Night", 'With Arms Outstretched'),
#  ('Rock Lobster', 'Imagine', "Here's to the Night", 'Otherside'),
#  ('Rock Lobster', 'Imagine', "Here's to the Night", 'Tonight, Tonight'),
#  ('Rock Lobster', 'Imagine', "Here's to the Night", "Let's Get it Started"),
#  ('Rock Lobster', 'Imagine', "Here's to the Night", 'Bad Romance'),
#  ('Rock Lobster', 'Imagine', "Here's to the Night", 'Just Dance'),
#  ('Rock Lobster', 'Imagine', "Here's to the Night", 'Hallelujah'),
#  ('Rock Lobster', 'Imagine', "Here's to the Night", 'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched'),
#  ('Rock Lobster', 'Imagine', 'Into the Aeroplane Over the Sea', 'Otherside'),
#  ('Rock Lobster',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight'),
#  ('Rock Lobster',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started"),
#  ('Rock Lobster', 'Imagine', 'Into the Aeroplane Over the Sea', 'Bad Romance'),
#  ('Rock Lobster', 'Imagine', 'Into the Aeroplane Over the Sea', 'Just Dance'),
#  ('Rock Lobster', 'Imagine', 'Into the Aeroplane Over the Sea', 'Hallelujah'),
#  ('Rock Lobster',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'Imagine', 'With Arms Outstretched', 'Otherside'),
#  ('Rock Lobster', 'Imagine', 'With Arms Outstretched', 'Tonight, Tonight'),
#  ('Rock Lobster', 'Imagine', 'With Arms Outstretched', "Let's Get it Started"),
#  ('Rock Lobster', 'Imagine', 'With Arms Outstretched', 'Bad Romance'),
#  ('Rock Lobster', 'Imagine', 'With Arms Outstretched', 'Just Dance'),
#  ('Rock Lobster', 'Imagine', 'With Arms Outstretched', 'Hallelujah'),
#  ('Rock Lobster', 'Imagine', 'With Arms Outstretched', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Imagine', 'Otherside', 'Tonight, Tonight'),
#  ('Rock Lobster', 'Imagine', 'Otherside', "Let's Get it Started"),
#  ('Rock Lobster', 'Imagine', 'Otherside', 'Bad Romance'),
#  ('Rock Lobster', 'Imagine', 'Otherside', 'Just Dance'),
#  ('Rock Lobster', 'Imagine', 'Otherside', 'Hallelujah'),
#  ('Rock Lobster', 'Imagine', 'Otherside', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Imagine', 'Tonight, Tonight', "Let's Get it Started"),
#  ('Rock Lobster', 'Imagine', 'Tonight, Tonight', 'Bad Romance'),
#  ('Rock Lobster', 'Imagine', 'Tonight, Tonight', 'Just Dance'),
#  ('Rock Lobster', 'Imagine', 'Tonight, Tonight', 'Hallelujah'),
#  ('Rock Lobster', 'Imagine', 'Tonight, Tonight', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Imagine', "Let's Get it Started", 'Bad Romance'),
#  ('Rock Lobster', 'Imagine', "Let's Get it Started", 'Just Dance'),
#  ('Rock Lobster', 'Imagine', "Let's Get it Started", 'Hallelujah'),
#  ('Rock Lobster', 'Imagine', "Let's Get it Started", 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Imagine', 'Bad Romance', 'Just Dance'),
#  ('Rock Lobster', 'Imagine', 'Bad Romance', 'Hallelujah'),
#  ('Rock Lobster', 'Imagine', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Imagine', 'Just Dance', 'Hallelujah'),
#  ('Rock Lobster', 'Imagine', 'Just Dance', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Imagine', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Otherside'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started"),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Just Dance'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Hallelujah'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Otherside'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Tonight, Tonight'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   "Let's Get it Started"),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Bad Romance'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Just Dance'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Hallelujah'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', "Here's to the Night", 'Otherside', 'Tonight, Tonight'),
#  ('Rock Lobster', "Here's to the Night", 'Otherside', "Let's Get it Started"),
#  ('Rock Lobster', "Here's to the Night", 'Otherside', 'Bad Romance'),
#  ('Rock Lobster', "Here's to the Night", 'Otherside', 'Just Dance'),
#  ('Rock Lobster', "Here's to the Night", 'Otherside', 'Hallelujah'),
#  ('Rock Lobster', "Here's to the Night", 'Otherside', 'Set Fire to the Rain'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Rock Lobster', "Here's to the Night", 'Tonight, Tonight', 'Bad Romance'),
#  ('Rock Lobster', "Here's to the Night", 'Tonight, Tonight', 'Just Dance'),
#  ('Rock Lobster', "Here's to the Night", 'Tonight, Tonight', 'Hallelujah'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Rock Lobster', "Here's to the Night", "Let's Get it Started", 'Just Dance'),
#  ('Rock Lobster', "Here's to the Night", "Let's Get it Started", 'Hallelujah'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Rock Lobster', "Here's to the Night", 'Bad Romance', 'Just Dance'),
#  ('Rock Lobster', "Here's to the Night", 'Bad Romance', 'Hallelujah'),
#  ('Rock Lobster',
#   "Here's to the Night",
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', "Here's to the Night", 'Just Dance', 'Hallelujah'),
#  ('Rock Lobster', "Here's to the Night", 'Just Dance', 'Set Fire to the Rain'),
#  ('Rock Lobster', "Here's to the Night", 'Hallelujah', 'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Otherside'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Tonight, Tonight'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   "Let's Get it Started"),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Bad Romance'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Just Dance'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Hallelujah'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Tonight, Tonight'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   "Let's Get it Started"),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Bad Romance'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Just Dance'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Hallelujah'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Bad Romance'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Just Dance'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Hallelujah'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Just Dance'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance',
#   'Just Dance'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance',
#   'Hallelujah'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Just Dance',
#   'Hallelujah'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'Into the Aeroplane Over the Sea',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'With Arms Outstretched', 'Otherside', 'Tonight, Tonight'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   'Otherside',
#   "Let's Get it Started"),
#  ('Rock Lobster', 'With Arms Outstretched', 'Otherside', 'Bad Romance'),
#  ('Rock Lobster', 'With Arms Outstretched', 'Otherside', 'Just Dance'),
#  ('Rock Lobster', 'With Arms Outstretched', 'Otherside', 'Hallelujah'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   'Otherside',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Rock Lobster', 'With Arms Outstretched', 'Tonight, Tonight', 'Bad Romance'),
#  ('Rock Lobster', 'With Arms Outstretched', 'Tonight, Tonight', 'Just Dance'),
#  ('Rock Lobster', 'With Arms Outstretched', 'Tonight, Tonight', 'Hallelujah'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Just Dance'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'With Arms Outstretched', 'Bad Romance', 'Just Dance'),
#  ('Rock Lobster', 'With Arms Outstretched', 'Bad Romance', 'Hallelujah'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'With Arms Outstretched', 'Just Dance', 'Hallelujah'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   'With Arms Outstretched',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'Otherside', 'Tonight, Tonight', "Let's Get it Started"),
#  ('Rock Lobster', 'Otherside', 'Tonight, Tonight', 'Bad Romance'),
#  ('Rock Lobster', 'Otherside', 'Tonight, Tonight', 'Just Dance'),
#  ('Rock Lobster', 'Otherside', 'Tonight, Tonight', 'Hallelujah'),
#  ('Rock Lobster', 'Otherside', 'Tonight, Tonight', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Otherside', "Let's Get it Started", 'Bad Romance'),
#  ('Rock Lobster', 'Otherside', "Let's Get it Started", 'Just Dance'),
#  ('Rock Lobster', 'Otherside', "Let's Get it Started", 'Hallelujah'),
#  ('Rock Lobster', 'Otherside', "Let's Get it Started", 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Otherside', 'Bad Romance', 'Just Dance'),
#  ('Rock Lobster', 'Otherside', 'Bad Romance', 'Hallelujah'),
#  ('Rock Lobster', 'Otherside', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Otherside', 'Just Dance', 'Hallelujah'),
#  ('Rock Lobster', 'Otherside', 'Just Dance', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Otherside', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Tonight, Tonight', "Let's Get it Started", 'Bad Romance'),
#  ('Rock Lobster', 'Tonight, Tonight', "Let's Get it Started", 'Just Dance'),
#  ('Rock Lobster', 'Tonight, Tonight', "Let's Get it Started", 'Hallelujah'),
#  ('Rock Lobster',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'Tonight, Tonight', 'Bad Romance', 'Just Dance'),
#  ('Rock Lobster', 'Tonight, Tonight', 'Bad Romance', 'Hallelujah'),
#  ('Rock Lobster', 'Tonight, Tonight', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Tonight, Tonight', 'Just Dance', 'Hallelujah'),
#  ('Rock Lobster', 'Tonight, Tonight', 'Just Dance', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Tonight, Tonight', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Rock Lobster', "Let's Get it Started", 'Bad Romance', 'Just Dance'),
#  ('Rock Lobster', "Let's Get it Started", 'Bad Romance', 'Hallelujah'),
#  ('Rock Lobster',
#   "Let's Get it Started",
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', "Let's Get it Started", 'Just Dance', 'Hallelujah'),
#  ('Rock Lobster',
#   "Let's Get it Started",
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Rock Lobster',
#   "Let's Get it Started",
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Rock Lobster', 'Bad Romance', 'Just Dance', 'Hallelujah'),
#  ('Rock Lobster', 'Bad Romance', 'Just Dance', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Bad Romance', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Rock Lobster', 'Just Dance', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Poker Face',
#   'Imagine',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea'),
#  ('Poker Face', 'Imagine', "Here's to the Night", 'With Arms Outstretched'),
#  ('Poker Face', 'Imagine', "Here's to the Night", 'Otherside'),
#  ('Poker Face', 'Imagine', "Here's to the Night", 'Tonight, Tonight'),
#  ('Poker Face', 'Imagine', "Here's to the Night", "Let's Get it Started"),
#  ('Poker Face', 'Imagine', "Here's to the Night", 'Bad Romance'),
#  ('Poker Face', 'Imagine', "Here's to the Night", 'Just Dance'),
#  ('Poker Face', 'Imagine', "Here's to the Night", 'Hallelujah'),
#  ('Poker Face', 'Imagine', "Here's to the Night", 'Set Fire to the Rain'),
#  ('Poker Face',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched'),
#  ('Poker Face', 'Imagine', 'Into the Aeroplane Over the Sea', 'Otherside'),
#  ('Poker Face',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight'),
#  ('Poker Face',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started"),
#  ('Poker Face', 'Imagine', 'Into the Aeroplane Over the Sea', 'Bad Romance'),
#  ('Poker Face', 'Imagine', 'Into the Aeroplane Over the Sea', 'Just Dance'),
#  ('Poker Face', 'Imagine', 'Into the Aeroplane Over the Sea', 'Hallelujah'),
#  ('Poker Face',
#   'Imagine',
#   'Into the Aeroplane Over the Sea',
#   'Set Fire to the Rain'),
#  ('Poker Face', 'Imagine', 'With Arms Outstretched', 'Otherside'),
#  ('Poker Face', 'Imagine', 'With Arms Outstretched', 'Tonight, Tonight'),
#  ('Poker Face', 'Imagine', 'With Arms Outstretched', "Let's Get it Started"),
#  ('Poker Face', 'Imagine', 'With Arms Outstretched', 'Bad Romance'),
#  ('Poker Face', 'Imagine', 'With Arms Outstretched', 'Just Dance'),
#  ('Poker Face', 'Imagine', 'With Arms Outstretched', 'Hallelujah'),
#  ('Poker Face', 'Imagine', 'With Arms Outstretched', 'Set Fire to the Rain'),
#  ('Poker Face', 'Imagine', 'Otherside', 'Tonight, Tonight'),
#  ('Poker Face', 'Imagine', 'Otherside', "Let's Get it Started"),
#  ('Poker Face', 'Imagine', 'Otherside', 'Bad Romance'),
#  ('Poker Face', 'Imagine', 'Otherside', 'Just Dance'),
#  ('Poker Face', 'Imagine', 'Otherside', 'Hallelujah'),
#  ('Poker Face', 'Imagine', 'Otherside', 'Set Fire to the Rain'),
#  ('Poker Face', 'Imagine', 'Tonight, Tonight', "Let's Get it Started"),
#  ('Poker Face', 'Imagine', 'Tonight, Tonight', 'Bad Romance'),
#  ('Poker Face', 'Imagine', 'Tonight, Tonight', 'Just Dance'),
#  ('Poker Face', 'Imagine', 'Tonight, Tonight', 'Hallelujah'),
#  ('Poker Face', 'Imagine', 'Tonight, Tonight', 'Set Fire to the Rain'),
#  ('Poker Face', 'Imagine', "Let's Get it Started", 'Bad Romance'),
#  ('Poker Face', 'Imagine', "Let's Get it Started", 'Just Dance'),
#  ('Poker Face', 'Imagine', "Let's Get it Started", 'Hallelujah'),
#  ('Poker Face', 'Imagine', "Let's Get it Started", 'Set Fire to the Rain'),
#  ('Poker Face', 'Imagine', 'Bad Romance', 'Just Dance'),
#  ('Poker Face', 'Imagine', 'Bad Romance', 'Hallelujah'),
#  ('Poker Face', 'Imagine', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Poker Face', 'Imagine', 'Just Dance', 'Hallelujah'),
#  ('Poker Face', 'Imagine', 'Just Dance', 'Set Fire to the Rain'),
#  ('Poker Face', 'Imagine', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched'),
#  ('Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Otherside'),
#  ('Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Tonight, Tonight'),
#  ('Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   "Let's Get it Started"),
#  ('Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Bad Romance'),
#  ('Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Just Dance'),
#  ('Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Hallelujah'),
#  ('Poker Face',
#   "Here's to the Night",
#   'Into the Aeroplane Over the Sea',
#   'Set Fire to the Rain'),
#  ('Poker Face', "Here's to the Night", 'With Arms Outstretched', 'Otherside'),
#  ('Poker Face',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Tonight, Tonight'),
#  ('Poker Face',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   "Let's Get it Started"),
#  ('Poker Face',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Bad Romance'),
#  ('Poker Face', "Here's to the Night", 'With Arms Outstretched', 'Just Dance'),
#  ('Poker Face', "Here's to the Night", 'With Arms Outstretched', 'Hallelujah'),
#  ('Poker Face',
#   "Here's to the Night",
#   'With Arms Outstretched',
#   'Set Fire to the Rain'),
#  ('Poker Face', "Here's to the Night", 'Otherside', 'Tonight, Tonight'),
#  ('Poker Face', "Here's to the Night", 'Otherside', "Let's Get it Started"),
#  ('Poker Face', "Here's to the Night", 'Otherside', 'Bad Romance'),
#  ('Poker Face', "Here's to the Night", 'Otherside', 'Just Dance'),
#  ('Poker Face', "Here's to the Night", 'Otherside', 'Hallelujah'),
#  ('Poker Face', "Here's to the Night", 'Otherside', 'Set Fire to the Rain'),
#  ('Poker Face',
#   "Here's to the Night",
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Poker Face', "Here's to the Night", 'Tonight, Tonight', 'Bad Romance'),
#  ('Poker Face', "Here's to the Night", 'Tonight, Tonight', 'Just Dance'),
#  ('Poker Face', "Here's to the Night", 'Tonight, Tonight', 'Hallelujah'),
#  ('Poker Face',
#   "Here's to the Night",
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Poker Face', "Here's to the Night", "Let's Get it Started", 'Bad Romance'),
#  ('Poker Face', "Here's to the Night", "Let's Get it Started", 'Just Dance'),
#  ('Poker Face', "Here's to the Night", "Let's Get it Started", 'Hallelujah'),
#  ('Poker Face',
#   "Here's to the Night",
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Poker Face', "Here's to the Night", 'Bad Romance', 'Just Dance'),
#  ('Poker Face', "Here's to the Night", 'Bad Romance', 'Hallelujah'),
#  ('Poker Face', "Here's to the Night", 'Bad Romance', 'Set Fire to the Rain'),
#  ('Poker Face', "Here's to the Night", 'Just Dance', 'Hallelujah'),
#  ('Poker Face', "Here's to the Night", 'Just Dance', 'Set Fire to the Rain'),
#  ('Poker Face', "Here's to the Night", 'Hallelujah', 'Set Fire to the Rain'),
#  ('Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Otherside'),
#  ('Poker Face',
#   'Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
# ...
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Otherside',
#   'Tonight, Tonight'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Otherside',
#   "Let's Get it Started"),
#  ("Here's to the Night", 'With Arms Outstretched', 'Otherside', 'Bad Romance'),
#  ("Here's to the Night", 'With Arms Outstretched', 'Otherside', 'Just Dance'),
#  ("Here's to the Night", 'With Arms Outstretched', 'Otherside', 'Hallelujah'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Otherside',
#   'Set Fire to the Rain'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Bad Romance'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Just Dance'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Hallelujah'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Just Dance'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Bad Romance',
#   'Just Dance'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Bad Romance',
#   'Hallelujah'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ("Here's to the Night", 'With Arms Outstretched', 'Just Dance', 'Hallelujah'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ("Here's to the Night",
#   'With Arms Outstretched',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ("Here's to the Night",
#   'Otherside',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ("Here's to the Night", 'Otherside', 'Tonight, Tonight', 'Bad Romance'),
#  ("Here's to the Night", 'Otherside', 'Tonight, Tonight', 'Just Dance'),
#  ("Here's to the Night", 'Otherside', 'Tonight, Tonight', 'Hallelujah'),
#  ("Here's to the Night",
#   'Otherside',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ("Here's to the Night", 'Otherside', "Let's Get it Started", 'Bad Romance'),
#  ("Here's to the Night", 'Otherside', "Let's Get it Started", 'Just Dance'),
#  ("Here's to the Night", 'Otherside', "Let's Get it Started", 'Hallelujah'),
#  ("Here's to the Night",
#   'Otherside',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ("Here's to the Night", 'Otherside', 'Bad Romance', 'Just Dance'),
#  ("Here's to the Night", 'Otherside', 'Bad Romance', 'Hallelujah'),
#  ("Here's to the Night", 'Otherside', 'Bad Romance', 'Set Fire to the Rain'),
#  ("Here's to the Night", 'Otherside', 'Just Dance', 'Hallelujah'),
#  ("Here's to the Night", 'Otherside', 'Just Dance', 'Set Fire to the Rain'),
#  ("Here's to the Night", 'Otherside', 'Hallelujah', 'Set Fire to the Rain'),
#  ("Here's to the Night",
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ("Here's to the Night",
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Just Dance'),
#  ("Here's to the Night",
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ("Here's to the Night",
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ("Here's to the Night", 'Tonight, Tonight', 'Bad Romance', 'Just Dance'),
#  ("Here's to the Night", 'Tonight, Tonight', 'Bad Romance', 'Hallelujah'),
#  ("Here's to the Night",
#   'Tonight, Tonight',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ("Here's to the Night", 'Tonight, Tonight', 'Just Dance', 'Hallelujah'),
#  ("Here's to the Night",
#   'Tonight, Tonight',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ("Here's to the Night",
#   'Tonight, Tonight',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ("Here's to the Night", "Let's Get it Started", 'Bad Romance', 'Just Dance'),
#  ("Here's to the Night", "Let's Get it Started", 'Bad Romance', 'Hallelujah'),
#  ("Here's to the Night",
#   "Let's Get it Started",
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ("Here's to the Night", "Let's Get it Started", 'Just Dance', 'Hallelujah'),
#  ("Here's to the Night",
#   "Let's Get it Started",
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ("Here's to the Night",
#   "Let's Get it Started",
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ("Here's to the Night", 'Bad Romance', 'Just Dance', 'Hallelujah'),
#  ("Here's to the Night", 'Bad Romance', 'Just Dance', 'Set Fire to the Rain'),
#  ("Here's to the Night", 'Bad Romance', 'Hallelujah', 'Set Fire to the Rain'),
#  ("Here's to the Night", 'Just Dance', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Otherside',
#   'Tonight, Tonight'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Otherside',
#   "Let's Get it Started"),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Otherside',
#   'Bad Romance'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Otherside',
#   'Just Dance'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Otherside',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Otherside',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Bad Romance'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Just Dance'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Just Dance'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Bad Romance',
#   'Just Dance'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Bad Romance',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Just Dance',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'With Arms Outstretched',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Tonight, Tonight',
#   'Bad Romance'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Tonight, Tonight',
#   'Just Dance'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Tonight, Tonight',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   "Let's Get it Started",
#   'Just Dance'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea', 'Otherside', 'Bad Romance', 'Just Dance'),
#  ('Into the Aeroplane Over the Sea', 'Otherside', 'Bad Romance', 'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea', 'Otherside', 'Just Dance', 'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Otherside',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Just Dance'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Bad Romance',
#   'Just Dance'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Bad Romance',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Just Dance',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Tonight, Tonight',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Bad Romance',
#   'Just Dance'),
#  ('Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Bad Romance',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Just Dance',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   "Let's Get it Started",
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Bad Romance',
#   'Just Dance',
#   'Hallelujah'),
#  ('Into the Aeroplane Over the Sea',
#   'Bad Romance',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Bad Romance',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Into the Aeroplane Over the Sea',
#   'Just Dance',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched',
#   'Otherside',
#   'Tonight, Tonight',
#   "Let's Get it Started"),
#  ('With Arms Outstretched', 'Otherside', 'Tonight, Tonight', 'Bad Romance'),
#  ('With Arms Outstretched', 'Otherside', 'Tonight, Tonight', 'Just Dance'),
#  ('With Arms Outstretched', 'Otherside', 'Tonight, Tonight', 'Hallelujah'),
#  ('With Arms Outstretched',
#   'Otherside',
#   'Tonight, Tonight',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched',
#   'Otherside',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('With Arms Outstretched', 'Otherside', "Let's Get it Started", 'Just Dance'),
#  ('With Arms Outstretched', 'Otherside', "Let's Get it Started", 'Hallelujah'),
#  ('With Arms Outstretched',
#   'Otherside',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched', 'Otherside', 'Bad Romance', 'Just Dance'),
#  ('With Arms Outstretched', 'Otherside', 'Bad Romance', 'Hallelujah'),
#  ('With Arms Outstretched',
#   'Otherside',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched', 'Otherside', 'Just Dance', 'Hallelujah'),
#  ('With Arms Outstretched', 'Otherside', 'Just Dance', 'Set Fire to the Rain'),
#  ('With Arms Outstretched', 'Otherside', 'Hallelujah', 'Set Fire to the Rain'),
#  ('With Arms Outstretched',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Bad Romance'),
#  ('With Arms Outstretched',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Just Dance'),
#  ('With Arms Outstretched',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Hallelujah'),
#  ('With Arms Outstretched',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched', 'Tonight, Tonight', 'Bad Romance', 'Just Dance'),
#  ('With Arms Outstretched', 'Tonight, Tonight', 'Bad Romance', 'Hallelujah'),
#  ('With Arms Outstretched',
#   'Tonight, Tonight',
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched', 'Tonight, Tonight', 'Just Dance', 'Hallelujah'),
#  ('With Arms Outstretched',
#   'Tonight, Tonight',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched',
#   'Tonight, Tonight',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched',
#   "Let's Get it Started",
#   'Bad Romance',
#   'Just Dance'),
#  ('With Arms Outstretched',
#   "Let's Get it Started",
#   'Bad Romance',
#   'Hallelujah'),
#  ('With Arms Outstretched',
#   "Let's Get it Started",
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched',
#   "Let's Get it Started",
#   'Just Dance',
#   'Hallelujah'),
#  ('With Arms Outstretched',
#   "Let's Get it Started",
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched',
#   "Let's Get it Started",
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched', 'Bad Romance', 'Just Dance', 'Hallelujah'),
#  ('With Arms Outstretched',
#   'Bad Romance',
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched',
#   'Bad Romance',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('With Arms Outstretched',
#   'Just Dance',
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Otherside', 'Tonight, Tonight', "Let's Get it Started", 'Bad Romance'),
#  ('Otherside', 'Tonight, Tonight', "Let's Get it Started", 'Just Dance'),
#  ('Otherside', 'Tonight, Tonight', "Let's Get it Started", 'Hallelujah'),
#  ('Otherside',
#   'Tonight, Tonight',
#   "Let's Get it Started",
#   'Set Fire to the Rain'),
#  ('Otherside', 'Tonight, Tonight', 'Bad Romance', 'Just Dance'),
#  ('Otherside', 'Tonight, Tonight', 'Bad Romance', 'Hallelujah'),
#  ('Otherside', 'Tonight, Tonight', 'Bad Romance', 'Set Fire to the Rain'),
#  ('Otherside', 'Tonight, Tonight', 'Just Dance', 'Hallelujah'),
#  ('Otherside', 'Tonight, Tonight', 'Just Dance', 'Set Fire to the Rain'),
#  ('Otherside', 'Tonight, Tonight', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Otherside', "Let's Get it Started", 'Bad Romance', 'Just Dance'),
#  ('Otherside', "Let's Get it Started", 'Bad Romance', 'Hallelujah'),
#  ('Otherside', "Let's Get it Started", 'Bad Romance', 'Set Fire to the Rain'),
#  ('Otherside', "Let's Get it Started", 'Just Dance', 'Hallelujah'),
#  ('Otherside', "Let's Get it Started", 'Just Dance', 'Set Fire to the Rain'),
#  ('Otherside', "Let's Get it Started", 'Hallelujah', 'Set Fire to the Rain'),
#  ('Otherside', 'Bad Romance', 'Just Dance', 'Hallelujah'),
#  ('Otherside', 'Bad Romance', 'Just Dance', 'Set Fire to the Rain'),
#  ('Otherside', 'Bad Romance', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Otherside', 'Just Dance', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Tonight, Tonight', "Let's Get it Started", 'Bad Romance', 'Just Dance'),
#  ('Tonight, Tonight', "Let's Get it Started", 'Bad Romance', 'Hallelujah'),
#  ('Tonight, Tonight',
#   "Let's Get it Started",
#   'Bad Romance',
#   'Set Fire to the Rain'),
#  ('Tonight, Tonight', "Let's Get it Started", 'Just Dance', 'Hallelujah'),
#  ('Tonight, Tonight',
#   "Let's Get it Started",
#   'Just Dance',
#   'Set Fire to the Rain'),
#  ('Tonight, Tonight',
#   "Let's Get it Started",
#   'Hallelujah',
#   'Set Fire to the Rain'),
#  ('Tonight, Tonight', 'Bad Romance', 'Just Dance', 'Hallelujah'),
#  ('Tonight, Tonight', 'Bad Romance', 'Just Dance', 'Set Fire to the Rain'),
#  ('Tonight, Tonight', 'Bad Romance', 'Hallelujah', 'Set Fire to the Rain'),
#  ('Tonight, Tonight', 'Just Dance', 'Hallelujah', 'Set Fire to the Rain'),
#  ("Let's Get it Started", 'Bad Romance', 'Just Dance', 'Hallelujah'),
#  ("Let's Get it Started", 'Bad Romance', 'Just Dance', 'Set Fire to the Rain'),
#  ("Let's Get it Started", 'Bad Romance', 'Hallelujah', 'Set Fire to the Rain'),
#  ("Let's Get it Started", 'Just Dance', 'Hallelujah', 'Set Fire to the Rain'),
#  ...]

# %%
# Calculate how many possible playlists
unique_playlists = math.comb(14, 1)
unique_playlists
# Out:
# 14

# %% [markdown]
# ### Q5: What if we limit the playlist to only 10 songs, without replacement? How many possible playlists?

# %%
# Calculate how many possible playlists
ten_songs = math.comb(14, 10)
ten_songs
# Out:
# 1001

# %% [markdown]
# ### Q6: What if we select 10 songs out of the total number of suggestions and allow for repetition?

# %%
# Calculate how many possible playlists

# %% [markdown]
# Hooray! Great job practicing probabilities and combinatorics!

# %% [markdown]
# ---
#
# ## Conditional Probability with Mushrooms
#
# #### When do we compute conditional probabilities?
#
# - We need to compute conditional probabilities when the outcome of an event depends on the outcome of previous events (dependent events). A conditional probability of an event is the probability of the event given another event has occurred.

# %% [markdown]
# ### Mushroom dataset
#
# To discuss conditional probability, let's look at a modified version of the Mushroom dataset from UCI [here](https://archive.ics.uci.edu/ml/datasets/Mushroom). Each row in this dataset corresponds to one observation (one mushroom).
#
# The modified dataset includes 4 variables:
#
# * **edible-poisonous**
#     * This categorical variable can have one of two values: if the mushroom is edible, "edible". If not, "poisonous"
#
# * **bruised**
#     * This is a Boolean variable that can assume either one of two values, True or False.
#
# * **gill-spacing**
#     * This categorical variable can have one of three values: "close", "crowded", or "distant"
#
# * **stalk-shape**
#     * This categorical variable can have one of two values: "enlarging" or "tapering"
# * **stalk-color-above-ring**
#     * This categorical variable can have one of nine values:  "brown","buff","cinnamon","gray","orange", "pink","red","white" or "yellow"
#
# * **stalk-color-below-ring**
#     * This categorical variable can have one of nine values:  "brown","buff","cinnamon","gray","orange", "pink","red","white" or "yellow"
#
# * **gill-color**
#     * This categorical variable can have one of twelve values: "black","brown","buff","chocolate","gray", "green","orange","pink","purple","red", "white" or "yellow"

# %%
df = pd.read_csv('../data/Mushrooms_cleaned.csv')
df.head()
# Out:
#   edible-poisonous gill-spacing stalk-shape stalk-color-above-ring  \
# 0        poisonous        close   enlarging                  white
# 1           edible        close   enlarging                  white
# 2           edible        close   enlarging                  white
# 3        poisonous        close   enlarging                  white
# 4           edible      crowded    tapering                  white
#
#   stalk-color-below-ring gill-color  bruised
# 0                  white      black     True
# 1                  white      black     True
# 2                  white      brown     True
# 3                  white      brown     True
# 4                  white      black    False

# %% [markdown]
# ### Q1: If you picked a row from this dataset at random, what is the probability it corresponds to a bruised mushroom?
#
# $P(bruised)$

# %%
df['bruised'].value_counts(normalize=True)[True]
# Out:
# 0.4155588380108321

# %%
# Calculate the probability of a bruised mushroom
p_bruised = df.loc[df['bruised'] == True].shape[0]/df.shape[0]
p_bruised
# Out:
# 0.4155588380108321

# %% [markdown]
# ### Q2: What is the probability you pick a row corresponding to a mushroom that is bruised _AND_ edible?
#
# $P(edible \cap bruised)$

# %%
# Calculate the probability of a bruised and edible mushroom
p_bruised_and_edible = df.loc[(df['bruised'] == True) & (df['edible-poisonous'] == 'edible')].shape[0]/df.shape[0]
p_bruised_and_edible
# Out:
# 0.33874938453963566

# %% [markdown]
# ### Q3: What is the probability of picking an edible mushroom given it is bruised?
#
# $P(edible | bruised)$

# %%
# Calculate the probability of an edible mushroom if you know it's bruised
p_edible_given_bruised = p_bruised_and_edible / p_bruised
p_edible_given_bruised
# Out:
# 0.8151658767772512

# %%
# to check
bruised = df.loc[df['bruised'] == True]
bruised['edible-poisonous'].value_counts(normalize=True)
# Out:
# edible       0.815166
# poisonous    0.184834
# Name: edible-poisonous, dtype: float64

# %% [markdown]
# ### Q4: What is the probability of picking a bruised mushroom given it is edible?
#
# $P(bruised | edible)$

# %%
# Calculate the probability of a bruised mushroom if you know it's edible
p_bruised_given_edible = None

# %% [markdown]
# ### Q5: What is the probability than a mushroom is edible if you can see that part of it is orange?
#
# $P(edible | orange)$
#
# Note - explore the data! Lots of parts of a mushroom could be orange!

# %%
# Explore the data and find which columns tell you about the mushroom's color

# %%
# Calculate the probability of an edible mushroom if you know part of it is orange
p_edible_given_orange = None

# %% [markdown]
# ## Level Up
#
# What's the probability that a mushroom is poisonous if it has close gill spacing and a tapering stalk?
#
# $P(edible|close \cap tapering)$

# %%
# P that mushroom is edible given close gill spacing and tapering stalk'
p_edible_given_close_tapering = None
